# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
data = pd.read_csv('bank.csv')

# %%
data
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
data.head(10)
# Out:
#    age         job   marital  education default  balance housing loan  \
# 0   59      admin.   married  secondary      no     2343     yes   no
# 1   56      admin.   married  secondary      no       45      no   no
# 2   41  technician   married  secondary      no     1270     yes   no
# 3   55    services   married  secondary      no     2476     yes   no
# 4   54      admin.   married   tertiary      no      184      no   no
# 5   42  management    single   tertiary      no        0     yes  yes
# 6   56  management   married   tertiary      no      830     yes  yes
# 7   60     retired  divorced  secondary      no      545     yes   no
# 8   37  technician   married  secondary      no        1     yes   no
# 9   28    services    single  secondary      no     5090     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may      1042         1     -1         0  unknown     yes
# ...

# %%
sns.heatmap(data.isnull() , yticklabels=False , cbar=False)
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
data.nunique()
# Out:
# age            76
# job            12
# marital         3
# education       4
# default         2
# balance      3805
# housing         2
# loan            2
# contact         3
# day            31
# month          12
# duration     1428
# campaign       36
# pdays         472
# previous       34
# poutcome        4
# deposit         2
# dtype: int64

# %%
data.head(5)
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
new_deposti = data.groupby('deposit')['deposit'].value_counts().reset_index()

# %%
new_deposti
# Out:
#   deposit  count
# 0      no   5873
# 1     yes   5289

# %%
import matplotlib.pyplot as plt

# %%
sns.countplot(data=new_deposti , x='deposit' , hue='count')
plt.title('Depoit How Much Yes Or Not')
plt.grid()
plt.show()

# %%
loan = data.groupby('loan')['loan'].value_counts().reset_index()
loan
# Out:
#   loan  count
# 0   no   9702
# 1  yes   1460

# %%
sns.displot(data=loan , x='loan' , hue='count')
plt.title('Here Is How Much Loan Yes Or no')
plt.show()

# %%
data['job'].unique()
# Out:
# array(['admin.', 'technician', 'services', 'management', 'retired',
#        'blue-collar', 'unemployed', 'entrepreneur', 'housemaid',
#        'unknown', 'self-employed', 'student'], dtype=object)

# %%
new_Job = data[(data['job']=='retired') & (data['age'])].value_counts().reset_index()
sord_values =  new_Job.sort_values(by='age' , ascending=True).head(10)
sord_values
# Out:
#      age      job   marital  education default  balance housing loan  \
# 0     35  retired    single    primary      no      434      no   no
# 99    37  retired   married  secondary      no       71      no  yes
# 270   41  retired  divorced    primary      no     -233     yes   no
# 269   41  retired    single    primary      no     2579      no   no
# 268   43  retired   married    primary      no     7298      no   no
# 267   43  retired   married  secondary      no      860      no   no
# 266   45  retired  divorced  secondary      no     1735      no  yes
# 265   45  retired    single  secondary     yes       86      no   no
# 264   47  retired   married    primary      no     1374      no  yes
# 262   47  retired    single    primary      no     3033      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 0      unknown    5   may       138         1     -1         0  unknown
# ...

# %%
sns.lineplot(data=sord_values , x='age' , y="job")
# Out:
# <Axes: xlabel='age', ylabel='job'>

# %%
new_data = data.groupby('education')['job'].value_counts().reset_index()
result = new_data.sort_values(by='job' , ascending=False).head(10)
result
# Out:
#     education         job  count
# 43    unknown     unknown     39
# 23  secondary     unknown     15
# 35   tertiary     unknown      9
# 11    primary     unknown      7
# 47    unknown  unemployed      7
# 30   tertiary  unemployed     84
# 5     primary  unemployed     56
# 18  secondary  unemployed    210
# 25   tertiary  technician    521
# 8     primary  technician     41

# %%
sns.lineplot(data=result , x='education' , y='count' , hue='job')
plt.grid()
plt.show()

# %%
data.head(10)
# Out:
#    age         job   marital  education default  balance housing loan  \
# 0   59      admin.   married  secondary      no     2343     yes   no
# 1   56      admin.   married  secondary      no       45      no   no
# 2   41  technician   married  secondary      no     1270     yes   no
# 3   55    services   married  secondary      no     2476     yes   no
# 4   54      admin.   married   tertiary      no      184      no   no
# 5   42  management    single   tertiary      no        0     yes  yes
# 6   56  management   married   tertiary      no      830     yes  yes
# 7   60     retired  divorced  secondary      no      545     yes   no
# 8   37  technician   married  secondary      no        1     yes   no
# 9   28    services    single  secondary      no     5090     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may      1042         1     -1         0  unknown     yes
# ...

# %%
data['marital'].unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
data['default'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data_se = data['default'].value_counts().reset_index()
data_se
# Out:
#   default  count
# 0      no  10994
# 1     yes    168

# %%
sns.countplot(data=data_se , x='default' , hue='count')
# Out:
# <Axes: xlabel='default', ylabel='count'>

# %%
data[['loan', 'age']]
# Out:
#       loan  age
# 0       no   59
# 1       no   56
# 2       no   41
# 3       no   55
# 4       no   54
# ...    ...  ...
# 11157   no   33
# 11158   no   39
# 11159   no   32
# 11160  yes   43
# 11161   no   34
#
# [11162 rows x 2 columns]

# %%
new_Data = data[data['age'] >  60]
result = new_Data['loan'].value_counts().reset_index()
result
# Out:
#   loan  count
# 0   no    602
# 1  yes      9

# %%
sns.barplot(data=result , x='loan' , y='count')
# Out:
# <Axes: xlabel='loan', ylabel='count'>

# %%
data['age'].max()
# Out:
# np.int64(95)

# %%
data['age'].min()
# Out:
# np.int64(18)

# %%
data['month'].unique()
# Out:
# array(['may', 'jun', 'jul', 'aug', 'oct', 'nov', 'dec', 'jan', 'feb',
#        'mar', 'apr', 'sep'], dtype=object)

# %%
data['poutcome'].unique()
# Out:
# array(['unknown', 'other', 'failure', 'success'], dtype=object)

# %%
rs = data[data['poutcome']=='success']
r_s = rs.groupby('poutcome')['month'].value_counts().reset_index()
r_s
# Out:
#    poutcome month  count
# 0   success   aug    146
# 1   success   may    136
# 2   success   feb    109
# 3   success   sep    106
# 4   success   oct    101
# 5   success   nov     95
# 6   success   jun     91
# 7   success   apr     86
# 8   success   jul     77
# 9   success   mar     48
# 10  success   jan     42
# 11  success   dec     34

# %%
sns.histplot(data=r_s , x='poutcome' , y='month')
# Out:
# <Axes: xlabel='poutcome', ylabel='month'>

# %%
sns.pairplot(data)

# %%
fig, [ax0, ax1, ax2] = plt.subplots(1,3, figsize = (14,4))
ax0.hist(data.education , color='red')
ax0.set_xlabel('education distribution')

ax1.hist(data.marital , color='red')
ax1.set_xlabel('marital distribution')


ax1.hist(data.marital , color='red')
ax1.set_xlabel('marital distribution')


ax2.hist(data.job , color='yellow')
ax2.set_xlabel('job distribution ')
# Out:
# Text(0.5, 0, 'job distribution ')

# %%
data.head(5)
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
new_sit = data['job'].value_counts().reset_index()

# %%
new_sit
# Out:
#               job  count
# 0      management   2566
# 1     blue-collar   1944
# 2      technician   1823
# 3          admin.   1334
# 4        services    923
# 5         retired    778
# 6   self-employed    405
# 7         student    360
# 8      unemployed    357
# 9    entrepreneur    328
# 10      housemaid    274
# 11        unknown     70

# %%
sns.lineplot(data=new_sit , x='job' , y='count')
# Out:
# <Axes: xlabel='job', ylabel='count'>

# %%
sns.boxplot(data=data)
# Out:
# <Axes: >

# %%
data.head(5)
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
for col in ['job' , 'marital' , 'education' , 'default' , 'housing' , 'loan' , 'contact' , 'month' , 'poutcome' , 'deposit']:
    print(f"{col}:{data[col].unique()}")
# Out:
# job:['admin.' 'technician' 'services' 'management' 'retired' 'blue-collar'
#  'unemployed' 'entrepreneur' 'housemaid' 'unknown' 'self-employed'
#  'student']
# marital:['married' 'single' 'divorced']
# education:['secondary' 'tertiary' 'primary' 'unknown']
# default:['no' 'yes']
# housing:['yes' 'no']
# loan:['no' 'yes']
# contact:['unknown' 'cellular' 'telephone']
# month:['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# poutcome:['unknown' 'other' 'failure' 'success']
# deposit:['yes' 'no']

# %%
for col in ['job','marital','education','default','balance','housing','loan','contact','day','month','duration','campaign','pdays','previous','poutcome','deposit']:
    print(f'{col}:{data[col].unique()}')
# Out:
# job:['admin.' 'technician' 'services' 'management' 'retired' 'blue-collar'
#  'unemployed' 'entrepreneur' 'housemaid' 'unknown' 'self-employed'
#  'student']
# marital:['married' 'single' 'divorced']
# education:['secondary' 'tertiary' 'primary' 'unknown']
# default:['no' 'yes']
# balance:[2343   45 1270 ... 1594 2593 -134]
# housing:['yes' 'no']
# loan:['no' 'yes']
# contact:['unknown' 'cellular' 'telephone']
# day:[ 5  6  7  8  9 12 13 14 15 16 19 20 21 23 26 27 28 29 30  2  3  4 11 17
#  18 24  1 10 22 25 31]
# month:['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# duration:[1042 1467 1389 ... 1504  818 1812]
# campaign:[ 1  2  3  4  6  5  8 11  9 10 15 12 14  7 24 13 17 29 21 20 16 32 19 25
#  22 43 18 41 63 27 30 26 23 28 33 31]
# pdays:[ -1 166  91 147 170 150 171 126 182 110 198 174 175  27 128 100 177 167
#  122 183 195 133 178  34  10 163 184 154  99  93   2 242 272  76 160  90
# ...

# %%
data
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
cat_col = ['job','marital','education','default','balance','housing','loan','contact','day','month','duration','campaign','pdays','previous','poutcome','deposit']
fig = plt.figure(figsize=(20,20))
for i,col in enumerate(cat_col):
    ax = fig.add_subplot(4 , 3 , i+1)
    sns.countplot(data=data , x=col )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 4
#       2 fig = plt.figure(figsize=(20,20))
#       3 for i,col in enumerate(cat_col):
# ----> 4     ax = fig.add_subplot(4 , 3 , i+1)
#       5     sns.countplot(data=data , x=col )
#
# File c:\Users\A PLUS COM\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\figure.py:768, in FigureBase.add_subplot(self, *args, **kwargs)
#     766         args = tuple(map(int, str(args[0])))
#     767     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 768     ax = projection_class(self, *args, **pkw)
#     769     key = (projection_class, pkw)
#     770 return self._add_axes_internal(ax, key)
#
# ...

# %%
for i in cat_col[:-1]:
    sns.countplot(data=data , x=col , hue='deposit')
    plt.xticks(rotation = 45)
    plt.title(f"{i} vs Deposit")
# Out:
# C:\Users\A PLUS COM\AppData\Roaming\Python\Python313\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\A PLUS COM\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
numeric_cols = ['balance' , 'day' , 'duration', 'campaign' , 'pdays' , 'previous']

corr = data[numeric_cols].corr()
plt.Figure(figsize=(10,6))
sns.heatmap(corr , annot=True , cmap='coolwarm')
# Out:
# <Axes: >

# %%
data
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
fig, [ax0, ax1, ax2] = plt.subplots(1,3, figsize = (14,4))
ax0.hist(data.education , color='red')
ax0.set_xlabel('education distribution')

ax1.hist(data.marital , color='red')
ax1.set_xlabel('marital distribution')


ax1.hist(data.marital , color='red')
ax1.set_xlabel('marital distribution')


ax2.hist(data.job , color='yellow')
ax2.set_xlabel('job distribution ')

# %%
data.head(5)
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes
